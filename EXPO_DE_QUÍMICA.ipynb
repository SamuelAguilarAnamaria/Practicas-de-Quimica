# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelAguilarAnamaria/Practicas-de-Quimica/blob/main/EXPO_DE_QU%C3%8DMICA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from math import *

# %% [markdown]
# ![q.jpeg](data:image/jpeg;base64,...)

# %%
# I.    Si se disuelven 45 g de cloruro de bario en 100 gramos de agua, a 80°C la disolución se enfría muy lentamente hasta 50°C sin que se observe precipitaciones. Se le agrega un cristal(de masa despreciable) de la sustancia y se observa que aparece un precipitado.
# II.   Indica que tipo de solución se tiene a los 50°C e indica cuantos gramos de cloruro de bario precipitan
# III.   Tenemos una solución saturada de cloruro de bario a 30°C y la calentamos hasta 50°C ¿Qué cantidad habrá que agregar a la disolución para saturarla de nuevo?

# %%
sq="/export?format=xlsx"
df=pd.read_excel ("https://docs.google.com/spreadsheets/d/1cgfjjFPrtL0zbSlb0GNHQXZuSy85awdzT8KLIRsd_Wg"+sq)
df
# Out:
#    gr BaCl/100 g de agua  T°C
# 0                   31.6    0
# 1                   33.3   10
# 2                   35.7   20
# 3                   38.2   30
# 4                   40.7   40
# 5                   43.6   50
# 6                   46.6   60
# 7                   49.4   70
# 8                   52.4   80
# 9                   58.8  100

# %%
plt.plot(df["T°C"],df["gr BaCl/100 g de agua"],label="Cloruro de bario")
plt.title("Solubilidad del BaCl")
plt.legend(title="")
plt.xlabel("Temperatura (C°)")
plt.ylabel("en 100g de agua ")
plt.xticks([0,10,20,30,40,50,60,70,80,100])
plt.yticks([31.6,33.3,35.7,38.2,40.7,43.6,46.6,49.4,52.4,58.8])
plt.grid()
plt.show()

# %%
a=float(input("ingrese la solubilida a 30°C "))
b=float(input("ingrese la solubilida a 50°C "))
result=(b-a)
print("para que la solucion este de nuevo satura se debe agregar ",result,"g de cloruro de bario")
# Out:
# ingrese la solubilida a 30°C 38.2
# ingrese la solubilida a 50°C 43.6
# para que la solucion este de nuevo satura se debe agregar  5.399999999999999 g de cloruro de bario

# %%
sq="/export?format=xlsx"
df2=pd.read_excel ("https://docs.google.com/spreadsheets/d/1nv8wmrglfa8qqOClGOzQ3g6LM2gujhbDBrOt6gCxI_Q"+sq)
df2
# Out:
#    gr KBr/100 g de agua  gr KI/100 g de agua  T°c
# 0                    65                  145   20
# 1                    80                  160   40
# 2                    90                  175   60
# 3                   100                  190   80
# 4                   110                  210  100

# %%
#1. Construya las grafica
#2. A medio litro de agua, le agregamos
#   495 g de de KBr, a una temperatura de
#   80°C. ¿Como es la solución obtenida?.
#3.  ¿Que pasaría si enfriamos la solución
#   hasta 40°C?

# %%
plt.plot(df2["T°c"],df2["gr KBr/100 g de agua"],label="bromuro de potasio")
plt.title("Solubilidad del KBr")
plt.legend(title="")
plt.xlabel("Temperatura (C°)")
plt.ylabel("en 100g de agua")
plt.xticks(np.arange(20,120,20))
plt.yticks([65,80,90,100,110])
plt.grid()
plt.show()

# %%
plt.plot(df2["T°c"],df2["gr KI/100 g de agua"],label="yoduro de potasio")
plt.title("Solubilidad del KI")
plt.legend(title="")
plt.xlabel("Temperatura (C°)")
plt.ylabel("en 100g de agua ")
plt.xticks([20,40,60,80,100])
plt.yticks([145,160,175,190,210])
plt.grid()
plt.show()
