# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelAguilarAnamaria/Practicas-de-Quimica/blob/main/AGUILAR_ANAMARIA%2C_SAMUEL_ALESSANDRO_GASES_(QU%C3%8DMICA_GENERAL).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install drawdata

# %%
from drawdata import draw_scatter, draw_histogram, draw_line

# %% [markdown]
# ![borrame.png](data:image/png;base64,...)

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df1 = pd.read_csv("/data.csv")

# %%
df1
# Out:
#          x      y  z
# 0    0.000  0.104  a
# 1    0.025  0.190  a
# 2    0.050  0.326  a
# 3    0.075  0.678  a
# 4    0.100  0.736  a
# ..     ...    ... ..
# 115  0.875  0.008  c
# 116  0.900  0.000  c
# 117  0.925  0.000  c
# 118  0.950  0.000  c
# 119  0.975  0.000  c
#
# [120 rows x 3 columns]

# %%
plt.scatter(df1["x"],df1["y"])

# %%
df1["x"].mean()
# Out:
# 0.4875

# %%
df1["x"].median()
# Out:
# 0.4875

# %%
df1["x"].std()
# Out:
# 0.28979491444291217

# %%
df1.describe()
# Out:
#                 x           y
# count  120.000000  120.000000
# mean     0.487500    0.195733
# std      0.289795    0.232130
# min      0.000000   -0.006000
# 25%      0.243750    0.000000
# 50%      0.487500    0.109000
# 75%      0.731250    0.327000
# max      0.975000    0.946000

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df2 = pd.read_csv("/data (3).csv")

# %%
df2
# Out:
#          x      y  z
# 0    0.000  0.148  a
# 1    0.025  0.372  a
# 2    0.050  0.664  a
# 3    0.075  0.918  a
# 4    0.100  0.940  a
# ..     ...    ... ..
# 115  0.875  0.046  c
# 116  0.900  0.032  c
# 117  0.925  0.020  c
# 118  0.950  0.008  c
# 119  0.975  0.002  c
#
# [120 rows x 3 columns]

# %%
plt.scatter(df2["x"],df2["y"])

# %%
df2["x"].mean()
# Out:
# 0.4875

# %%
df2["x"].median()
# Out:
# 0.4875

# %%
df2["x"].std()
# Out:
# 0.28979491444291217

# %%
df2.describe()
# Out:
#                 x           y
# count  120.000000  120.000000
# mean     0.487500    0.189850
# std      0.289795    0.232848
# min      0.000000    0.000000
# 25%      0.243750    0.000000
# 50%      0.487500    0.108000
# 75%      0.731250    0.297500
# max      0.975000    0.940000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       120 non-null    float64
#  1   y       120 non-null    float64
#  2   z       120 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.9+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       120 non-null    float64
#  1   y       120 non-null    float64
#  2   z       120 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.9+ KB
